# %%
import urllib.request
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = urllib.request.urlopen(url)
from bs4 import BeautifulSoup
soup = BeautifulSoup(page, "lxml")

# %%
all_tables=soup.findAll("table")
all_tables
# Out:
# [<table class="wikitable">
#  <tbody><tr>
#  <th>Postal code
#  </th>
#  <th>Borough
#  </th>
#  <th>Neighborhood
#  </th></tr>
#  <tr>
#  <td>M1A
#  </td>
#  <td>Not assigned
#  </td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>M2A
#  </td>
#  <td>Not assigned
#  </td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>M3A
#  </td>
#  <td>North York
#  </td>
#  <td>Parkwoods
#  </td></tr>
#  <tr>
#  <td>M4A
#  </td>
#  <td>North York
#  </td>
#  <td>Victoria Village
#  </td></tr>
#  <tr>
#  <td>M5A
#  </td>
#  <td>Downtown Toronto
#  </td>
#  <td>Regent Park / Harbourfront
#  </td></tr>
#  <tr>
#  <td>M6A
#  </td>
#  <td>North York
#  </td>
#  <td>Lawrence Manor / Lawrence Heights
#  </td></tr>
#  <tr>
#  <td>M7A
#  </td>
#  <td>Downtown Toronto
#  </td>
#  <td>Queen's Park / Ontario Provincial Government
#  </td></tr>
#  <tr>
#  <td>M8A
#  </td>
#  <td>Not assigned
#  </td>
#  <td>
#  </td></tr>
#  <tr>
#  <td>M9A
#  </td>
#  <td>Etobicoke
#  </td>
#  <td>Islington Avenue
#  </td></tr>
#  <tr>
# ...

# %%
right_table = soup.find('table',{'class':'wikitable'})
right_table
# Out:
# <table class="wikitable">
# <tbody><tr>
# <th>Postal code
# </th>
# <th>Borough
# </th>
# <th>Neighborhood
# </th></tr>
# <tr>
# <td>M1A
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>
# <tr>
# <td>M2A
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>
# <tr>
# <td>M3A
# </td>
# <td>North York
# </td>
# <td>Parkwoods
# </td></tr>
# <tr>
# <td>M4A
# </td>
# <td>North York
# </td>
# <td>Victoria Village
# </td></tr>
# <tr>
# <td>M5A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Regent Park / Harbourfront
# </td></tr>
# <tr>
# <td>M6A
# </td>
# <td>North York
# </td>
# <td>Lawrence Manor / Lawrence Heights
# </td></tr>
# <tr>
# <td>M7A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Queen's Park / Ontario Provincial Government
# </td></tr>
# <tr>
# <td>M8A
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>
# <tr>
# <td>M9A
# </td>
# <td>Etobicoke
# </td>
# <td>Islington Avenue
# </td></tr>
# <tr>
# <td>M1B
# </td>
# <td>Scarborough
# </td>
# <td>Malvern / Rouge
# </td></tr>
# ...

# %%
A=[]
B=[]
C=[]
for row in right_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))

# %%
import pandas as pd
df=pd.DataFrame(A,columns=['Postcode'])
df['Borough']=B
df['Neighborhood']=C
df.head()
# Out:
#   Postcode            Borough                 Neighborhood
# 0     M1A
#       Not assigned
#
#
# 1     M2A
#       Not assigned
#
#
# 2     M3A
#         North York
#                    Parkwoods
#
# 3     M4A
#         North York
#             Victoria Village
#
# 4     M5A
#   Downtown Toronto
#   Regent Park / Harbourfront

# %%
df = df.dropna(inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-001fac4f806a> in <module>
#       1
# ----> 2 df = df.dropna(inplace=True)
#       3 df.head()
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
#df1 = df[df['Borough'] != 'Not assigned'].reset_index(drop=True)
#df1.head()
df2 = df[df['Borough'] != 'Not assigned' ].index
df.drop(df2 , inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-33eb6549d11e> in <module>
#       1 #df1 = df[df['Borough'] != 'Not assigned'].reset_index(drop=True)
#       2 #df1.head()
# ----> 3 df2 = df[df['Borough'] != 'Not assigned' ].index
#       4 df.drop(df2 , inplace=True)
#       5 df.head()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df.Neighborhood.replace(np.NaN)
df1 = df[df['Neighborhood'] != np.NaN].reset_index(drop=True)
df1.head()
# Out:
#   Postcode            Borough                 Neighborhood
# 0     M1A
#       Not assigned
#
#
# 1     M2A
#       Not assigned
#
#
# 2     M3A
#         North York
#                    Parkwoods
#
# 3     M4A
#         North York
#             Victoria Village
#
# 4     M5A
#   Downtown Toronto
#   Regent Park / Harbourfront

# %%
df= df[df.Borough != 'Not assigned']
df = df.sort_values(by=['Postcode','Borough'])
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)
df
# Out:
#     Postcode        Borough                                       Neighborhood
# 0       M1A
#   Not assigned
#
#
# 1       M1B
#    Scarborough
#                                    Malvern / Rouge
#
# 2       M1C
#    Scarborough
#           Rouge Hill / Port Union / Highland Creek
#
# 3       M1E
#    Scarborough
#                Guildwood / Morningside / West Hill
#
# 4       M1G
#    Scarborough
#                                             Woburn
#
# 5       M1H
#    Scarborough
#                                          Cedarbrae
#
# 6       M1J
#    Scarborough
#                                Scarborough Village
#
# 7       M1K
#    Scarborough
#      Kennedy Park / Ionview / East Birchmount Park
#
# 8       M1L
#    Scarborough
#                  Golden Mile / Clairlea / Oakridge
#
# 9       M1M
#    Scarborough
#   Cliffside / Cliffcrest / Scarborough Village W...
# 10      M1N
#    Scarborough
#                       Birch Cliff / Cliffside West
#
# 11      M1P
# ...

# %%
df.drop(df.index[df['Borough']== 'Not assigned'].inplace=True)
df = df.reset_index(drop = True)
df.head()
# Out:
#   File "<ipython-input-157-bc9c9e64237d>", line 1
#     df.drop(df.index[df['Borough']== 'Not assigned'].inplace=True)
#            ^
# SyntaxError: keyword can't be an expression

# %% [raw]
# df.drop(['Not assigned'],inplace=True)

# %%
df= df.dropna("Not assigned",inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-7856d739bfe0> in <module>
# ----> 1 df= df.dropna("Not assigned",inplace=True)
#       2 df.head()
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4570                                        axis=ax)
#    4571         else:
# -> 4572             axis = self._get_axis_number(axis)
#    4573             agg_axis = 1 - axis
#    4574
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     359                 pass
#     360         raise ValueError('No axis named {0} for object type {1}'
# --> 361                          .format(axis, type(cls)))
#     362
#     363     @classmethod
#
# ValueError: No axis named Not assigned for object type <class 'type'>
